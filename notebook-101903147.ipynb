# %%
#Importing libraries
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
import cudf as cd
import cupy as cp
df_train=cd.read_csv('/kaggle/input/ucl-ai-society-football-match-prediction/Kaggle Data/train.csv')
df_test=cd.read_csv('/kaggle/input/ucl-ai-society-football-match-prediction/Kaggle Data/test.csv')
df_train

# %%
print(df_train.shape)
print(list(df_train.columns))
df_train.head()

# %%
df_train=df_train.drop('id',axis=1)
ids=df_test['id'].copy()
df_test=df_test.drop('id',axis=1)
df_train

# %%
y=df_train['Outcome'].copy()
df_train=df_train.drop('Outcome',axis=1)

# %%
df=cd.concat((df_train,df_test))
df

# %%
from cuml.preprocessing.LabelEncoder import LabelEncoder
enc=LabelEncoder()
enc.fit(df)
df=enc.transform(df)
df

# %%
#data exploration 
df['y'].value_counts()
sns.countplot(x='y',data=data,palette='hls')
plt.show()
plt.savfig('count_plot')

# %%
#data visualization
# %matplotlib inline
pd.crosstab(data.home_team,data.y).plot(kind='bar')
plt.title('Stacked ba chart of home_team')
plt.xlabel('home_team')
plt.ylabel('Outcome')

table=pd.crosstab(data.away_team,data.y)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked bar chart of away_team')
plt.xlabel('away_team')
plt.ylabel('Outcome')

table=pd.crosstab(data.country,data.y)
table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Stacked Bar Chart of country ')
plt.xlabel('Education')
plt.ylabel('Proportion of Customers')


pd.crosstab(data.neutral,data.y).plot(kind='bar')
plt.title('Stacked bar chart for neutral')
plt.xlabel('neutral')
plt.ylabel('Outcome')

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(df_test, df_pred)
print(confusion_matrix)

# %%
from sklearn.metrics import classification_report
print(classification_report(df_test, df_pred))
